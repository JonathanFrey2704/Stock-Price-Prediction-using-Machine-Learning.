# %%
import os
import sys
from pathlib import Path
from LSTM import downloadData
from LSTM import run_LSTM, print_pred
import pandas as pd

# %%
df = downloadData('SPY','2016-12-12')
#Available features 'Volume', 'RSI', 'ATR'
#Enter features you want to input to the model in feautures list
features =[]
run_LSTM(df, features)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# Overview of data:
#                  Close
# Date
# 2016-12-12  209.491821
# 2016-12-13  210.889969
# 2016-12-14  209.149246
# 2016-12-15  210.010361
# 2016-12-16  209.599579
#
#
# Overview of scaled data:
# [[0.00803316]
#  [0.01668202]
#  [0.00591401]
#  [0.01124081]]
#
#
# Training model...
# Epoch 1/5
# 744/744 - 22s - loss: 0.0032
# Epoch 2/5
# 744/744 - 20s - loss: 0.0010
# Epoch 3/5
# 744/744 - 20s - loss: 7.2532e-04
# Epoch 4/5
# 744/744 - 21s - loss: 7.1392e-04
# Epoch 5/5
# 744/744 - 20s - loss: 5.3076e-04
# Root Mean Squared Error = 7.721686841332615

# %%
print_pred()
# Out:
#                  Close  Predictions
# Date
# 2020-02-25  308.226624   327.181488
# 2020-02-26  307.092926   317.830658
# 2020-02-27  293.300873   312.074066
# 2020-02-28  292.068542   303.741425
# 2020-03-02  304.716980   298.575012
# 2020-03-03  295.992218   302.860229
# 2020-03-04  308.433655   304.066132
# 2020-03-05  298.180817   309.407501
# 2020-03-06  293.251556   308.971710
# 2020-03-09  270.350220   304.584045
# 2020-03-10  284.339478   290.726898
# 2020-03-11  270.478394   286.491119
# 2020-03-12  244.599762   280.539246
# 2020-03-13  265.509674   267.432861
# 2020-03-16  236.456635   265.806000
# 2020-03-17  249.223404   257.534119
# 2020-03-18  236.604492   255.003662
# 2020-03-19  237.107269   250.518509
# 2020-03-20  226.889328   247.269745
# 2020-03-23  221.088181   242.394119
# 2020-03-24  241.119492   237.186905
# 2020-03-25  244.729095   239.597382
# 2020-03-26  259.018768   244.739609
# 2020-03-27  251.303726   253.718933
# 2020-03-30  259.464996   258.140381
# ...
